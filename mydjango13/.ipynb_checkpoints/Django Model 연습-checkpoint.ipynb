# %%
import os
os.environ["DJANGO_SETTINGS_MODULE"]="mydjango13.settings"
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import django
django.setup()

# %%
from mall.models import Shop

# %%
Shop.objects.all()
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" LIMIT 21; args=()
# <QuerySet []>

# %%
Shop
# Out:
# mall.models.Shop

# %% [markdown]
# # Create

# %%
shop = Shop() # class name은 대문자로 시작
shop.name="투썸플레이스"
shop.telephone="042-1234-1234"

# %%
shop.save()
# Out:
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('투썸플레이스', '', '042-1234-1234', '', '2021-12-01 06:33:07.906897', '2021-12-01 06:33:07.906897'); args=['투썸플레이스', '', '042-1234-1234', '', '2021-12-01 06:33:07.906897', '2021-12-01 06:33:07.906897']

# %%
shop=Shop.objects.create(
    name="셀프24시빨래방",
    telephone="042-9876-9876",
)
shop
# Out:
# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('셀프24시빨래방', '', '042-9876-9876', '', '2021-12-01 06:33:08.892170', '2021-12-01 06:33:08.892170'); args=['셀프24시빨래방', '', '042-9876-9876', '', '2021-12-01 06:33:08.892170', '2021-12-01 06:33:08.892170']
# <Shop: Shop object (2)>

# %% [markdown]
# # Select

# %%
qs= Shop.objects.all()

# %%
for shop in qs:
    print(shop.pk, shop.name, shop.telephone)
# Out:
# (0.016) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop"; args=()
# 1 투썸플레이스 042-1234-1234
# 2 셀프24시빨래방 042-9876-9876

# %%
qs.order_by("-id") #, "created_at") # -는 내림차순 정렬 (정렬은 가급적 단일 컬럼을 쓰기)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" ORDER BY "mall_shop"."id" DESC, "mall_shop"."created_at" ASC LIMIT 21; args=()
# <QuerySet [<Shop: Shop object (2)>, <Shop: Shop object (1)>]>

# %% [markdown]
# # 데이터 뻥튀기

# %%
for i in range(1,101):
    name = f"가게명#{i}"
    telephone = f"042-1234-9{i:03}"
    Shop.objects.create(
        name=name,
        telephone=telephone,
    )
# Out:
# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#1', '', '042-1234-9001', '', '2021-12-01 06:45:31.566177', '2021-12-01 06:45:31.566177'); args=['가게명#1', '', '042-1234-9001', '', '2021-12-01 06:45:31.566177', '2021-12-01 06:45:31.566177']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#2', '', '042-1234-9002', '', '2021-12-01 06:45:31.589643', '2021-12-01 06:45:31.589643'); args=['가게명#2', '', '042-1234-9002', '', '2021-12-01 06:45:31.589643', '2021-12-01 06:45:31.589643']
# (0.000) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#3', '', '042-1234-9003', '', '2021-12-01 06:45:31.597874', '2021-12-01 06:45:31.597874'); args=['가게명#3', '', '042-1234-9003', '', '2021-12-01 06:45:31.597874', '2021-12-01 06:45:31.597874']
# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#4', '', '042-1234-9004', '', '2021-12-01 06:45:31.604855', '2021-12-01 06:45:31.604855'); args=['가게명#4', '', '042-1234-9004', '', '2021-12-01 06:45:31.604855', '2021-12-01 06:45:31.604855']
# (0.000) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#5', '', '042-1234-9005', '', '2021-12-01 06:45:31.611836', '2021-12-01 06:45:31.611836'); args=['가게명#5', '', '042-1234-9005', '', '2021-12-01 06:45:31.611836', '2021-12-01 06:45:31.611836']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#6', '', '042-1234-9006', '', '2021-12-01 06:45:31.619814', '2021-12-01 06:45:31.619814'); args=['가게명#6', '', '042-1234-9006', '', '2021-12-01 06:45:31.619814', '2021-12-01 06:45:31.619814']
# (0.000) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#7', '', '042-1234-9007', '', '2021-12-01 06:45:31.628791', '2021-12-01 06:45:31.628791'); args=['가게명#7', '', '042-1234-9007', '', '2021-12-01 06:45:31.628791', '2021-12-01 06:45:31.628791']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명

# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#97', '', '042-1234-9097', '', '2021-12-01 06:45:32.472818', '2021-12-01 06:45:32.472818'); args=['가게명#97', '', '042-1234-9097', '', '2021-12-01 06:45:32.472818', '2021-12-01 06:45:32.472818']
# (0.000) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#98', '', '042-1234-9098', '', '2021-12-01 06:45:32.484617', '2021-12-01 06:45:32.484617'); args=['가게명#98', '', '042-1234-9098', '', '2021-12-01 06:45:32.484617', '2021-12-01 06:45:32.484617']
# (0.000) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#99', '', '042-1234-9099', '', '2021-12-01 06:45:32.492596', '2021-12-01 06:45:32.492596'); args=['가게명#99', '', '042-1234-9099', '', '2021-12-01 06:45:32.492596', '2021-12-01 06:45:32.492596']
# (0.000) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#100', '', '042-1234-9100', '', '2021-12-01 06:45:32.499578', '2021-12-01 06:45:32.499578'); args=['가게명#100', '', '042-1234-9100', '', '2021-12-01 06:45:32.499578', '2021-12-01 06:45:32.499578']

# %% [markdown]
# # Slicing

# %%
qs=Shop.objects.all()

# %%
qs[:10]
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" LIMIT 10; args=()
# <QuerySet [<Shop: Shop object (1)>, <Shop: Shop object (2)>, <Shop: Shop object (3)>, <Shop: Shop object (4)>, <Shop: Shop object (5)>, <Shop: Shop object (6)>, <Shop: Shop object (7)>, <Shop: Shop object (8)>, <Shop: Shop object (9)>, <Shop: Shop object (10)>]>

# %%
qs[0:10:2]
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" LIMIT 10; args=()
# [<Shop: Shop object (1)>,
#  <Shop: Shop object (3)>,
#  <Shop: Shop object (5)>,
#  <Shop: Shop object (7)>,
#  <Shop: Shop object (9)>]

# %%
qs[-10:] # last 10 rows -> 디비에서 지원 안함

# %%
for shop in reversed(qs.order_by("id")[:10]):
    print(shop.pk, shop.name, shop.telephone)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" ORDER BY "mall_shop"."id" ASC LIMIT 10; args=()
# 10 가게명#8 042-1234-9008
# 9 가게명#7 042-1234-9007
# 8 가게명#6 042-1234-9006
# 7 가게명#5 042-1234-9005
# 6 가게명#4 042-1234-9004
# 5 가게명#3 042-1234-9003
# 4 가게명#2 042-1234-9002
# 3 가게명#1 042-1234-9001
# 2 셀프24시빨래방 042-9876-9876
# 1 투썸플레이스 042-1234-1234

# %% [markdown]
# # Conditions

# %%
qs=Shop.objects.all()

# %%
# filter <-> exclude

qs.filter(pk=1)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" = 1 LIMIT 21; args=(1,)
# <QuerySet [<Shop: Shop object (1)>]>

# %%
qs.exclude(pk=1)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE NOT ("mall_shop"."id" = 1) LIMIT 21; args=(1,)
# <QuerySet [<Shop: Shop object (2)>, <Shop: Shop object (3)>, <Shop: Shop object (4)>, <Shop: Shop object (5)>, <Shop: Shop object (6)>, <Shop: Shop object (7)>, <Shop: Shop object (8)>, <Shop: Shop object (9)>, <Shop: Shop object (10)>, <Shop: Shop object (11)>, <Shop: Shop object (12)>, <Shop: Shop object (13)>, <Shop: Shop object (14)>, <Shop: Shop object (15)>, <Shop: Shop object (16)>, <Shop: Shop object (17)>, <Shop: Shop object (18)>, <Shop: Shop object (19)>, <Shop: Shop object (20)>, <Shop: Shop object (21)>, '...(remaining elements truncated)...']>

# %%
# lt: less than             <
# lte: less than equal      <=
# gt: greater than          >
# gte: greather than equal  >=
qs.filter(
    pk__gte=5,
    pk__lt=10, #less than
)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" < 10 LIMIT 21; args=(10,)
# <QuerySet [<Shop: Shop object (1)>, <Shop: Shop object (2)>, <Shop: Shop object (3)>, <Shop: Shop object (4)>, <Shop: Shop object (5)>, <Shop: Shop object (6)>, <Shop: Shop object (7)>, <Shop: Shop object (8)>, <Shop: Shop object (9)>]>

# %%
qs.filter(pk__gte=5).filter(pk__lt=10)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE ("mall_shop"."id" >= 5 AND "mall_shop"."id" < 10) LIMIT 21; args=(5, 10)
# <QuerySet [<Shop: Shop object (5)>, <Shop: Shop object (6)>, <Shop: Shop object (7)>, <Shop: Shop object (8)>, <Shop: Shop object (9)>]>

# %%
qs1 = Shop.objects.all()
qs1 = qs1.filter(pk__gte=5)
qs1 = qs1.filter(pk__lt=10)

# %%
qs2 = Shop.objects.all().filter(pk__gte=5).filter(pk__lt=10)

# %%
# QuerySet is Lazy

# %%
qs=Shop.objects.all()

# %%
Shop.objects.all()
# Out:
# (0.016) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" LIMIT 21; args=()
# <QuerySet [<Shop: Shop object (1)>, <Shop: Shop object (2)>, <Shop: Shop object (3)>, <Shop: Shop object (4)>, <Shop: Shop object (5)>, <Shop: Shop object (6)>, <Shop: Shop object (7)>, <Shop: Shop object (8)>, <Shop: Shop object (9)>, <Shop: Shop object (10)>, <Shop: Shop object (11)>, <Shop: Shop object (12)>, <Shop: Shop object (13)>, <Shop: Shop object (14)>, <Shop: Shop object (15)>, <Shop: Shop object (16)>, <Shop: Shop object (17)>, <Shop: Shop object (18)>, <Shop: Shop object (19)>, <Shop: Shop object (20)>, '...(remaining elements truncated)...']>

# %%
qs=Shop.objects.all()
shop_list=list(qs) # 사용하기 좋지 않다
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop"; args=()

# %% [markdown]
# # Get 1 Row

# %%
pk=10
not_existed_pk=1000000

# %%
shop=Shop.objects.get(pk=pk) # 가져올 대상이 1개임을 기대. 1개가 아니면 예외가 발생
shop
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" = 10 LIMIT 21; args=(10,)
# <Shop: Shop object (10)>

# %%
Shop.objects.get(pk=not_existed_pk) #Shop.DoseNotExist 예외가 발생
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" = 1000000 LIMIT 21; args=(1000000,)
# ------------------------------------------------------------------------
# DoesNotExist                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9796/2870484627.py in <module>
# ----> 1 Shop.objects.get(pk=not_existed_pk) #Shop.DoseNotExist 예외가 발생
#
# C:\Python310\lib\site-packages\django\db\models\manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# C:\Python310\lib\site-packages\django\db\models\query.py in get(self, *args, **kwargs)
#     433             return clone._result_cache[0]
#     434         if not num:
# --> 435             raise self.model.DoesNotExist(
#     436                 "%s matching query does not exist." %
#     437                 self.model._meta.object_name
#
# DoesNotExist: Shop matching query does not exist.

# %%
Shop.objects.filter(pk=pk)[0]
shop
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" = 10 LIMIT 1; args=(10,)
# <Shop: Shop object (10)>

# %%
Shop.objects.filter(pk=not_existed_pk)[0] # indexError 예외가 발생

# %%
Shop.objects.filter(pk=not_existed_pk).first() # 지정 Row가 없다면 None을 반환할 뿐, 예외는 발생 x
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" = 1000000 ORDER BY "mall_shop"."id" ASC LIMIT 1; args=(1000000,)

# %% [markdown]
# # Conditions (OR)

# %%
qs=Shop.objects.all()
qs.filter(pk__gte=5, pk__lt=10) #AND
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE ("mall_shop"."id" >= 5 AND "mall_shop"."id" < 10) LIMIT 21; args=(5, 10)
# <QuerySet [<Shop: Shop object (5)>, <Shop: Shop object (6)>, <Shop: Shop object (7)>, <Shop: Shop object (8)>, <Shop: Shop object (9)>]>

# %%
from django.db.models import Q

# %%
Q(pk__gte=5)
# Out:
# <Q: (AND: ('pk__gte', 5))>

# %%
Q(pk__lt=10)
# Out:
# <Q: (AND: ('pk__lt', 10))>

# %%
Q(pk__gte=5) & Q(pk__lt=10)
# Out:
# <Q: (AND: ('pk__gte', 5), ('pk__lt', 10))>

# %%
Q(pk__gte=5) | Q(pk__lt=10)
# Out:
# <Q: (OR: ('pk__gte', 5), ('pk__lt', 10))>

# %%
qs = Shop.objects.all()
qs.filter(
    Q(pk__gte=5) | Q(pk__lt=10)
)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE ("mall_shop"."id" >= 5 OR "mall_shop"."id" < 10) LIMIT 21; args=(5, 10)
# <QuerySet [<Shop: Shop object (5)>, <Shop: Shop object (6)>, <Shop: Shop object (7)>, <Shop: Shop object (8)>, <Shop: Shop object (9)>, <Shop: Shop object (10)>, <Shop: Shop object (11)>, <Shop: Shop object (12)>, <Shop: Shop object (13)>, <Shop: Shop object (14)>, <Shop: Shop object (15)>, <Shop: Shop object (16)>, <Shop: Shop object (17)>, <Shop: Shop object (18)>, <Shop: Shop object (19)>, <Shop: Shop object (20)>, <Shop: Shop object (21)>, <Shop: Shop object (22)>, <Shop: Shop object (23)>, <Shop: Shop object (24)>, '...(remaining elements truncated)...']>

# %%
conditions =  Q(pk__gte=5)
# conditions = conditions | Q(pk__lt=10)
conditions |= Q(pk__lt=10)

conditions
# Out:
# <Q: (OR: ('pk__gte', 5), ('pk__lt', 10))>

# %% [markdown]
# # Update Rows

# %% [markdown]
# 지정 Row

# %%
qs = Shop.objects.all()
shop=qs.get(pk=10)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" = 10 LIMIT 21; args=(10,)

# %%
shop.name, shop.telephone
# Out:
# ('가게명#8', '042-1234-9008')

# %%
shop.telephone='042-1234-0006'

# %%
shop.save()
# Out:
# (0.016) UPDATE "mall_shop" SET "name" = '가게명#8', "description" = '', "telephone" = '042-1234-0006', "photo" = '', "created_at" = '2021-12-01 06:45:31.636770', "updated_at" = '2021-12-01 07:39:07.433030' WHERE "mall_shop"."id" = 10; args=('가게명#8', '', '042-1234-0006', '', '2021-12-01 06:45:31.636770', '2021-12-01 07:39:07.433030', 10)

# %% [markdown]
# # 지정 범위의 Rows

# %%
qs = Shop.objects.all()
qs = qs.filter(pk__lte=10)
qs.update(
    description="not used description",
)
# Out:
# (0.000) UPDATE "mall_shop" SET "description" = 'not used description' WHERE "mall_shop"."id" <= 10; args=('not used description', 10)
# 10

# %%
qs = Shop.objects.all()
qs = qs.filter(pk__lte=10)
for shop in qs:
    shop.description='not used description'
    shop.save()
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" <= 10; args=(10,)
# (0.047) UPDATE "mall_shop" SET "name" = '투썸플레이스', "description" = 'not used description', "telephone" = '042-1234-1234', "photo" = '', "created_at" = '2021-12-01 06:33:07.906897', "updated_at" = '2021-12-01 07:43:49.511467' WHERE "mall_shop"."id" = 1; args=('투썸플레이스', 'not used description', '042-1234-1234', '', '2021-12-01 06:33:07.906897', '2021-12-01 07:43:49.511467', 1)
# (0.000) UPDATE "mall_shop" SET "name" = '셀프24시빨래방', "description" = 'not used description', "telephone" = '042-9876-9876', "photo" = '', "created_at" = '2021-12-01 06:33:08.892170', "updated_at" = '2021-12-01 07:43:49.549473' WHERE "mall_shop"."id" = 2; args=('셀프24시빨래방', 'not used description', '042-9876-9876', '', '2021-12-01 06:33:08.892170', '2021-12-01 07:43:49.549473', 2)
# (0.016) UPDATE "mall_shop" SET "name" = '가게명#1', "description" = 'not used description', "telephone" = '042-1234-9001', "photo" = '', "created_at" = '2021-12-01 06:45:31.566177', "updated_at" = '2021-12-01 07:43:49.558430' WHERE "mall_shop"."id" = 3; args=('가게명#1', 'not used description', '042-1234-9001', '', '2021-12-01 06:45:31.566177', '2021-12-01 07:43:49.558430', 3)
# (0.000) UPDATE "mall_shop" SET "name" = '가게명#2', "description" = 'not used description', "telephone" = '042-1234-9002', "photo" = '', "created_at" = '2021-12-01 06:45:31.589643', "updated_at" = '2021-12-01 07:43:49.569401' WHERE "mall_shop"."id" = 4; args=('가게명#2', 'not used description', '042-1234-9002', '', '2021-12-01 06:45:31.589643', '2021-12-01 07:43:49.569401', 4)
# (0.000) UPDATE "mall_shop" SET "name" = '가게명#3', "description" = 'not used description', "telephone" = '042-1234-9003', "photo" = '', "created_at" = '2021-12-01 06:45:31.597874', "updated_at" = '2021-12-01 07:43:49.577421' WHERE "mall_shop"."id" = 5; args=('가게명#3', 'not used description', '042-1234-9003', '', '2021-12-01 06:45:31.597874', '2021-12-01 07:43:49.577421', 5)
# (0.016) UPDATE "mall_shop" SET "name" = '가게명#4', "description" = 'not used description', "telephone" = '042-1234-9004', "photo" = '', "created_at" = '2021-12-01 06:45:31.604855', "updated_at" = '2021-12-01 07:43:49.591342' WHERE "mall_shop"."id" = 6; args=('가게명#4', 'not used description', '042-1234-9004', '', '2021-12-01 06:45:31.604855', '2021-12-01 07:43:49.591342', 6)
# (0.015) UPDATE "mall_shop" SET "name" = '가게명#5', "description" = 'not used description', "telephone" = '042-1234-9005', "photo" = '', "created_at" = '2021-12-01 06:45:31.611836', "updated_at" = '2021-12-01 07:43:49.602333' WHERE "mall_shop"."id" = 7; args=('가게명#5', 'not used description', '042-1234-9005', '', '2021-12-01 06:45:31.611836', '2021-12-01 07:43:49.602333', 7)
# (0.000) UPDATE "mall_shop" SET "name" = '가게명#6', "description" = 'not used description', "telephone" = '042-1234-9006', "photo" = '', "created_at" = '2021-12-01 06:45:31.619814', "updated_at" = '2021-12-01 07:43:49.610312' WHERE "mall_shop"."id" = 8; args=('가게명#6', 'not used description', '042-1234-9006', '', '2021-12-01 06:45:31.619814', '2021-12-01 07:43:49.610312', 8)
# (0.016) UPDATE "mall_shop" SET "name" = '가게명#7', "description" = 'not used description', "telephone" = '042-1234-9007', "photo" = '', "created_at" = '2021-12-01 06:45:31.628791', "updated_at" = '2021-12-01 07:43:49.622259' WHERE "mall_shop"."id" = 9; args=('가게명#7', 'not used description', '042-1234-9007', '', '2021-12-01 06:45:31.628791', '2021-12-01 07:43:49.622259', 9)
# (0.016) UPDATE "mall_shop" SET "name" = '가게명#8', "description" = 'not used description', "telephone" = '042-1234-0006', "photo" = '', "created_at" = '2021-12-01 06:45:31.636770', "updated_at" = '2021-12-01 07:43:49.633236' WHERE "mall_shop"."id" = 10; args=('가게명#8', 'not used description', '042-1234-0006', '', '2021-12-01 06:45:31.636770', '2021-12-01 07:43:49.633236', 10)

# %% [markdown]
# # Delete Rows

# %%
# qs = Shop.objects.all()

# %%
# qs.delete()
